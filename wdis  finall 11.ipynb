# %%
import pandas as pd
import seaborn as sns
import numpy as np

# %%
s = pd.read_csv(r"C:/Users/User/Desktop/train_data.csv")

# %%
df=pd.DataFrame(s)
df
# Out:
#          index  lat       lon startdate  contest-pevpr-sfc-gauss-14d__pevpr  \
# 0            0  0.0  0.833333    9/1/14                              237.00
# 1            1  0.0  0.833333    9/2/14                              228.90
# 2            2  0.0  0.833333    9/3/14                              220.69
# 3            3  0.0  0.833333    9/4/14                              225.28
# 4            4  0.0  0.833333    9/5/14                              237.24
# ...        ...  ...       ...       ...                                 ...
# 375729  375729  1.0  0.866667   8/27/16                              312.05
# 375730  375730  1.0  0.866667   8/28/16                              305.82
# 375731  375731  1.0  0.866667   8/29/16                              311.62
# 375732  375732  1.0  0.866667   8/30/16                              304.54
# 375733  375733  1.0  0.866667   8/31/16                              295.29
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 375734 entries, 0 to 375733
# Columns: 246 entries, index to wind-vwnd-925-2010-20
# dtypes: float64(240), int64(4), object(2)
# memory usage: 705.2+ MB

# %%
# 'sst-2010-1',
#  'sst-2010-2',
#  'sst-2010-3',
#  'sst-2010-4',
#  'sst-2010-5',
#  'sst-2010-6',
#  'sst-2010-7',
#  'sst-2010-8',
#  'sst-2010-9',
#  'sst-2010-10'
col2=df.filter(like="sst-2010").columns
df["sst_2010_mean"] = df[col2].mean(axis=1)
df.drop(columns=col2,inplace=True)

# %%
len(df.columns)
# Out:
# 237

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 375734 entries, 0 to 375733
# Columns: 237 entries, index to sst_2010_mean
# dtypes: float64(231), int64(4), object(2)
# memory usage: 679.4+ MB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 375734 entries, 0 to 375733
# Columns: 237 entries, index to sst_2010_mean
# dtypes: float64(231), int64(4), object(2)
# memory usage: 679.4+ MB

# %%
df.describe()
# Out:
#                index            lat            lon  \
# count  375734.000000  375734.000000  375734.000000
# mean   187866.500000       0.592766       0.517964
# std    108465.207359       0.251744       0.272059
# min         0.000000       0.000000       0.000000
# 25%     93933.250000       0.409091       0.300000
# 50%    187866.500000       0.590909       0.533333
# 75%    281799.750000       0.818182       0.766667
# max    375733.000000       1.000000       1.000000
#
#        contest-pevpr-sfc-gauss-14d__pevpr  nmme0-tmp2m-34w__cancm30  \
# count                       375734.000000             375734.000000
# mean                           276.744064                 10.801682
# std                            198.085182                 10.952417
# min                             -2.310000                -14.960000
# 25%                            104.062500                  1.550000
# 50%                            250.320000                  9.950000
# ...

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# nmme0-tmp2m-34w__ccsm30    15934
# nmme0-prate-56w__ccsm30    15934
# nmme0-prate-34w__ccsm30    15934
# ccsm30                     15934
# nmme-tmp2m-56w__ccsm3      10280
#                            ...
# wind-vwnd-925-2010-17          0
# wind-vwnd-925-2010-18          0
# wind-vwnd-925-2010-19          0
# wind-vwnd-925-2010-20          0
# sst_2010_mean                  0
# Length: 237, dtype: int64

# %%
cols_to_drop=[

    "nmme0-prate-34w__ccsm30",
     "nmme0-tmp2m-34w__ccsm30",
     "ccsm30",
     "nmme0-prate-56w__ccsm30",
     "nmme-tmp2m-56w__ccsm3"

]
df=df.drop(columns=cols_to_drop)

# %%
# df.isnull().sum().sort_values(ascending=False)

# %%
# missing_precent=df.isnull().mean()*100
# missing_precent.sort_values(ascending=False)

# %%
miss_colum=[
    "nmme-prate-56w__ccsm3",
    "nmme-prate-34w__ccsm3",
    "nmme-tmp2m-34w__ccsm3"
]
# for col in miss_colum:
#\     df[col].fillna(df[col].mean(),inplace=True)

# %%
df[miss_colum].isnull().sum()
# Out:
# nmme-prate-56w__ccsm3    10280
# nmme-prate-34w__ccsm3     8738
# nmme-tmp2m-34w__ccsm3     8738
# dtype: int64

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# nmme-prate-56w__ccsm3                 10280
# nmme-prate-34w__ccsm3                  8738
# nmme-tmp2m-34w__ccsm3                  8738
# index                                     0
# contest-pevpr-sfc-gauss-14d__pevpr        0
#                                       ...
# wind-vwnd-925-2010-17                     0
# wind-vwnd-925-2010-18                     0
# wind-vwnd-925-2010-19                     0
# wind-vwnd-925-2010-20                     0
# sst_2010_mean                             0
# Length: 232, dtype: int64

# %%
# # df["lat"]
sns.stripplot(x="lat",y="sst_2010_mean",data=df)
# Out:
# <Axes: xlabel='lat', ylabel='sst_2010_mean'>

# %%
sns.histplot(x="lat",data=df)
# Out:
# <Axes: xlabel='lat', ylabel='Count'>

# %%
# sns.histplot("contest-tmp2m-14d__tmp2m")
sns.displot(df["contest-tmp2m-14d__tmp2m"])

# %%
# to_drop

# %%
df["nmme0_tmp2m_34w_mean"] = df.filter(like="nmme0-tmp2m-34w").mean(axis=1)


df = df.drop(columns=df.filter(like="nmme0-tmp2m-34w").columns)

# %%
col=df.filter(like="icec-2010").columns
df["icec_2010_mean"]=df[col].mean(axis=1)
df.drop(columns=col, inplace=True)

# %%
# wind-hgt-850-2010  
col=df.filter(like="wind-hgt-850-2010").columns
df["wind-hgt-850-2010_mean"]=df[col].mean(axis=1)
df.drop(columns=col, inplace=True)

# %%
#  wind-uwnd-925-2010
col=df.filter(like="wind-uwnd-925-2010").columns
df["wind-uwnd-925-2010_mean"]=df[col].mean(axis=1)
df.drop(columns=col, inplace=True)

# %%
col=df.filter(like="wind-hgt-500-2010").columns
df["wind-hgt-500-2010_mean"]=df[col].mean(axis=1)
df.drop(columns=col, inplace=True)

# %%
col=df.filter(like="wind-vwnd-250-2010").columns
df["wind-vwnd-250-2010_mean"]=df[col].mean(axis=1)
df.drop(columns=col, inplace=True)

# %%
col=df.filter(like="wind-uwnd-250-2010").columns
df["wind-uwnd-250-2010_mean"]=df[col].mean(axis=1)
df.drop(columns=col, inplace=True)

# %%
# df.drop(columns = ['nmme0-tmp2m-34w__cancm30',"nmme0-tmp2m-34w__cancm40","nmme0-tmp2m-34w__ccsm40","nmme0-tmp2m-34w__ccsm40","nmme0-tmp2m-34w__cfsv20","nmme0-tmp2m-34w__gfdlflora0","nmme0-tmp2m-34w__gfdlflorb0","nmme0-tmp2m-34w__gfdl0","nmme0-tmp2m-34w__nasa0"] ,inplace = True)
# df.drop(columns=[
#     'nmme0-tmp2m-34w__cancm30',
#     "nmme0-tmp2m-34w__cancm40",
#     "nmme0-tmp2m-34w__ccsm40",
#     "nmme0-tmp2m-34w__cfsv20",
#     "nmme0-tmp2m-34w__gfdlflora0",
#     "nmme0-tmp2m-34w__gfdlflorb0",
#     "nmme0-tmp2m-34w__gfdl0",
#     "nmme0-tmp2m-34w__nasa0"
# ], inplace=True, errors='ignore')
cols_to_drop = [
    'nmme0-tmp2m-34w__cancm30',
    "nmme0-tmp2m-34w__cancm40",
    "nmme0-tmp2m-34w__ccsm40",
    "nmme0-tmp2m-34w__cfsv20",
    "nmme0-tmp2m-34w__gfdlflora0",
    "nmme0-tmp2m-34w__gfdlflorb0",
    "nmme0-tmp2m-34w__gfdl0",
    "nmme0-tmp2m-34w__nasa0"
]

cols_exist = [col for col in cols_to_drop if col in df.columns]
df.drop(columns=cols_exist, inplace=True)

# %%
cols_to_drop = [
    'nmme0-prate-56w__gfdlflora0',
    'nmme0-prate-56w__gfdlflorb0',
    'nmme0-prate-56w__gfdl0',
    'nmme0-prate-56w__nasa0'
]


cols_exist = [col for col in cols_to_drop if col in df.columns]
df.drop(columns=cols_exist, inplace=True)

# %%
col =df.filter(like="wind-vwnd-925-2010").columns
df["wind-vwnd-925-2010_mean"]=df[col].mean(axis=1)
df.drop(columns=col,inplace=True)

# %%
# wind-hgt-10-2010
col =df.filter(like="wind-hgt-10-2010").columns
df["wind-hgt-10-2010_mean"]=df[col].mean(axis=1)
df.drop(columns=col,inplace=True)

# %%
col =df.filter(like="wind-hgt-100-2010").columns
df["wind-hgt-100-2010_mean"]=df[col].mean(axis=1)
df.drop(columns=col,inplace=True)

# %%
cols_to_drop = [
    'nmme-tmp2m-56w__cancm3',
    'nmme-tmp2m-56w__cancm4',
    'nmme-tmp2m-56w__ccsm4',
    'nmme-tmp2m-56w__cfsv2',
    'nmme-tmp2m-56w__gfdl',
    'nmme-tmp2m-56w__gfdlflora',
    'nmme-tmp2m-56w__gfdlflorb',
    'nmme-tmp2m-56w__nasa'
]


cols_exist = [col for col in cols_to_drop if col in df.columns]
df.drop(columns=cols_exist, inplace=True)

# %%
# 
cols_to_drop = [
    'nmme-prate-34w__cancm3',
    'nmme-prate-34w__cancm4',
    'nmme-prate-34w__ccsm3',
    'nmme-prate-34w__ccsm4',
    'nmme-prate-34w__cfsv2',
    'nmme-prate-34w__gfdl',
    'nmme-prate-34w__gfdlflora',
    'nmme-prate-34w__gfdlflorb',
    'nmme-prate-34w__nasa'
]

# 
cols_exist = [col for col in cols_to_drop if col in df.columns]
df.drop(columns=cols_exist, inplace=True)

# %%
cols_to_drop = [
    'nmme0-prate-56w__cancm30',
    'nmme0-prate-56w__cancm40',
    'nmme0-prate-56w__ccsm40',
    'nmme0-prate-56w__cfsv20'
]


cols_exist = [col for col in cols_to_drop if col in df.columns]
df.drop(columns=cols_exist, inplace=True)

# %%
cols_to_drop = [
    'nmme-prate-56w__cancm3',
    'nmme-prate-56w__cancm4',
    'nmme-prate-56w__ccsm3',
    'nmme-prate-56w__ccsm4',
    'nmme-prate-56w__cfsv2',
    'nmme-prate-56w__gfdl',
    'nmme-prate-56w__gfdlflora',
    'nmme-prate-56w__gfdlflorb',
    'nmme-prate-56w__nasa'
]


cols_exist = [col for col in cols_to_drop if col in df.columns]
df.drop(columns=cols_exist, inplace=True)

# %%
cols_to_drop = [
    'nmme0-prate-34w__cancm30',
    'nmme0-prate-34w__cancm40',
    'nmme0-prate-34w__ccsm40',
    'nmme0-prate-34w__cfsv20',
    'nmme0-prate-34w__gfdlflora0',
    'nmme0-prate-34w__gfdlflorb0',
    'nmme0-prate-34w__gfdl0',
    'nmme0-prate-34w__nasa0'
]


cols_exist = [col for col in cols_to_drop if col in df.columns]
df.drop(columns=cols_exist, inplace=True)

# %%
cols_to_drop = [
 'nmme-tmp2m-34w__cancm3',
 'nmme-tmp2m-34w__cancm4',
 'nmme-tmp2m-34w__ccsm3',
 'nmme-tmp2m-34w__ccsm4',
 'nmme-tmp2m-34w__cfsv2',
 'nmme-tmp2m-34w__gfdl',
 'nmme-tmp2m-34w__gfdlflora',
 'nmme-tmp2m-34w__gfdlflorb',
 'nmme-tmp2m-34w__nasa'
]

df.drop(columns=cols_to_drop, inplace=True)

# %%
nmme0_models = [
    "cancm30", "cancm40", "ccsm40", "cfsv20",
    "gfdlflora0", "gfdlflorb0", "gfdl0", "nasa0"
]


df.drop(columns=nmme0_models, inplace=True, errors="ignore")

# %%
len(df.columns)
# Out:
# 44

# %%
import seaborn as sns

# %%
import seaborn as sns
import matplotlib.pyplot as plt


a = df.select_dtypes(include=["int64", "float64"])


corr = a.corr()


target_corr = corr["contest-tmp2m-14d__tmp2m"].sort_values(ascending=False)
#
plt.figure(figsize=(6,10))
sns.heatmap(target_corr.to_frame(), annot=True, cmap="coolwarm", cbar=False)
plt.title("Correlation with target (contest-tmp2m-14d__tmp2m)")
plt.show()

# %%
sns.barplot(x="climateregions__climateregion",y="elevation__elevation",data=df)
# Out:
# <Axes: xlabel='climateregions__climateregion', ylabel='elevation__elevation'>

# %%
sns.scatterplot(x=df["nmme-tmp2m-56w__nmmemean"], 
                y=df["contest-tmp2m-14d__tmp2m"])
# Out:
# <Axes: xlabel='nmme-tmp2m-56w__nmmemean', ylabel='contest-tmp2m-14d__tmp2m'>

# %%
# sns.PairGrid(data=df)

# %%
sns.boxplot(x="climateregions__climateregion",y="contest-rhum-sig995-14d__rhum",data=df)
# Out:
# <Axes: xlabel='climateregions__climateregion', ylabel='contest-rhum-sig995-14d__rhum'>

# %%
sns.violinplot(x="climateregions__climateregion",y="contest-wind-h850-14d__wind-hgt-850",data=df)
# Out:
# <Axes: xlabel='climateregions__climateregion', ylabel='contest-wind-h850-14d__wind-hgt-850'>

# %%
df[["contest-tmp2m-14d__tmp2m","nmme0mean","nmme-tmp2m-56w__nmmemean"]].corr()
# Out:
#                           contest-tmp2m-14d__tmp2m  nmme0mean  \
# contest-tmp2m-14d__tmp2m                  1.000000   0.745223
# nmme0mean                                 0.745223   1.000000
# nmme-tmp2m-56w__nmmemean                  0.950865   0.794877
#
#                           nmme-tmp2m-56w__nmmemean
# contest-tmp2m-14d__tmp2m                  0.950865
# nmme0mean                                 0.794877
# nmme-tmp2m-56w__nmmemean                  1.000000

# %%
# 
df["startdate"] = pd.to_datetime(df["startdate"], errors="coerce")
df["year"] = df["startdate"].dt.year
df["month"] = df["startdate"].dt.month

sns.boxplot(x="year" ,y="nmme0mean",data=df)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_8348\629421563.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df["startdate"] = pd.to_datetime(df["startdate"], errors="coerce")
# <Axes: xlabel='year', ylabel='nmme0mean'>

# %%
sns.boxplot(x="climateregions__climateregion" ,y="contest-prwtr-eatm-14d__prwtr",data=df)
# Out:
# <Axes: xlabel='climateregions__climateregion', ylabel='contest-prwtr-eatm-14d__prwtr'>

# %%
sns.boxplot(x="month" ,y="contest-rhum-sig995-14d__rhum",data=df)
# Out:
# <Axes: xlabel='month', ylabel='contest-rhum-sig995-14d__rhum'>

# %%
sns.pairplot(df[["contest-tmp2m-14d__tmp2m", "nmme0mean", "nmme-tmp2m-56w__nmmemean"]])

# %%
sns.scatterplot(x="contest-tmp2m-14d__tmp2m",y="icec_2010_mean",data=df)
# Out:
# <Axes: xlabel='contest-tmp2m-14d__tmp2m', ylabel='icec_2010_mean'>

# %%
plt.figure(figsize=(8,5))
sns.scatterplot(x="lat", y="contest-tmp2m-14d__tmp2m",
                hue="climateregions__climateregion", data=df, alpha=0.7,legend=True)
plt.title("Target vs Latitude (Colored by Climate Region)")
plt.legend(loc="center right", bbox_to_anchor=(1.25, 0.5))

plt.show()

# %%
plt.figure(figsize=(12,5))
sns.lineplot(x="startdate", y="contest-tmp2m-14d__tmp2m", data=df)
plt.title("Target Temperature Trend Over Time")
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.histplot(df["elevation__elevation"], bins=30, kde=True)
plt.title("Distribution of Elevation")
plt.show()

# %%
df.head()
# Out:
#    index  lat       lon  startdate  contest-pevpr-sfc-gauss-14d__pevpr  \
# 0      0  0.0  0.833333 2014-09-01                              237.00
# 1      1  0.0  0.833333 2014-09-02                              228.90
# 2      2  0.0  0.833333 2014-09-03                              220.69
# 3      3  0.0  0.833333 2014-09-04                              225.28
# 4      4  0.0  0.833333 2014-09-05                              237.24
#
#    contest-wind-h10-14d__wind-hgt-10  nmme-tmp2m-56w__nmmemean  \
# 0                           31246.63                     28.11
# 1                           31244.78                     28.11
# 2                           31239.27                     28.11
# 3                           31232.86                     28.11
# 4                           31226.16                     28.11
#
#    contest-rhum-sig995-14d__rhum  nmme-prate-34w__nmmemean  \
# 0                          81.72                     24.02
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 375734 entries, 0 to 375733
# Data columns (total 46 columns):
#  #   Column                                    Non-Null Count   Dtype
# ---  ------                                    --------------   -----
#  0   index                                     375734 non-null  int64
#  1   lat                                       375734 non-null  float64
#  2   lon                                       375734 non-null  float64
#  3   startdate                                 375734 non-null  datetime64[ns]
#  4   contest-pevpr-sfc-gauss-14d__pevpr        375734 non-null  float64
#  5   contest-wind-h10-14d__wind-hgt-10         375734 non-null  float64
#  6   nmme-tmp2m-56w__nmmemean                  375734 non-null  float64
#  7   contest-rhum-sig995-14d__rhum             375734 non-null  float64
#  8   nmme-prate-34w__nmmemean                  375734 non-null  float64
# ...

# %%
my_columns = df.columns.tolist()
(my_columns)
# Out:
# ['index',
#  'lat',
#  'lon',
#  'startdate',
#  'contest-pevpr-sfc-gauss-14d__pevpr',
#  'contest-wind-h10-14d__wind-hgt-10',
#  'nmme-tmp2m-56w__nmmemean',
#  'contest-rhum-sig995-14d__rhum',
#  'nmme-prate-34w__nmmemean',
#  'contest-wind-h100-14d__wind-hgt-100',
#  'nmme0-prate-56w__nmme0mean',
#  'nmme0-prate-34w__nmme0mean',
#  'contest-tmp2m-14d__tmp2m',
#  'contest-slp-14d__slp',
#  'contest-wind-vwnd-925-14d__wind-vwnd-925',
#  'nmme-prate-56w__nmmemean',
#  'contest-pres-sfc-gauss-14d__pres',
#  'contest-wind-uwnd-250-14d__wind-uwnd-250',
#  'nmme-tmp2m-34w__nmmemean',
#  'contest-prwtr-eatm-14d__prwtr',
#  'contest-wind-vwnd-250-14d__wind-vwnd-250',
#  'contest-precip-14d__precip',
#  'contest-wind-h850-14d__wind-hgt-850',
#  'contest-wind-uwnd-925-14d__wind-uwnd-925',
#  'contest-wind-h500-14d__wind-hgt-500',
#  'nmme0mean',
#  'climateregions__climateregion',
#  'elevation__elevation',
#  'mjo1d__phase',
#  'mjo1d__amplitude',
#  'mei__mei',
#  'mei__meirank',
# ...

# %%
df.drop(columns=["startdate"],axis=1,inplace=True)

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.metrics import mean_squared_error
from sklearn.impute import SimpleImputer
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import Ridge

from xgboost import XGBRegressor

from lightgbm import LGBMRegressor
from catboost import CatBoostRegressor
Train1 = pd.read_csv(r"C:/Users/User/Desktop/train_data.csv")
valdation  = pd.read_csv(r"C:/Users/User/Desktop/sample_solution.csv")
testing = pd.read_csv(r"C:/Users/User/Desktop/test_data.csv")

target_col = "contest-tmp2m-14d__tmp2m"
my_45_columns = [
    'index','lat','lon','contest-pevpr-sfc-gauss-14d__pevpr',
    'contest-wind-h10-14d__wind-hgt-10','nmme-tmp2m-56w__nmmemean',
    'contest-rhum-sig995-14d__rhum','nmme-prate-34w__nmmemean',
    'contest-wind-h100-14d__wind-hgt-100','nmme0-prate-56w__nmme0mean',
    'nmme0-prate-34w__nmme0mean','contest-tmp2m-14d__tmp2m',
    'contest-slp-14d__slp','contest-wind-vwnd-925-14d__wind-vwnd-925',
    'nmme-prate-56w__nmmemean','contest-pres-sfc-gauss-14d__pres',
    'contest-wind-uwnd-250-14d__wind-uwnd-250','nmme-tmp2m-34w__nmmemean',
    'contest-prwtr-eatm-14d__prwtr','contest-wind-vwnd-250-14d__wind-vwnd-250',
    'contest-precip-14d__precip','contest-wind-h850-14d__wind-hgt-850',
    'contest-wind-uwnd-925-14d__wind-uwnd-925','contest-wind-h500-14d__wind-hgt-500',
    'nmme0mean','wind-vwnd-925-2010_mean','wind-hgt-10-2010_mean',
    'wind-hgt-100-2010_mean','year','month'
]
X_train = Train1[[c for c in my_45_columns if c in Train1.columns]]
y_train = Train1[target_col]
X_valdation = valdation[[c for c in my_45_columns if c in valdation.columns]]
y_valdation = valdation[target_col]
for col in my_45_columns:
     if col  not in X_valdation.columns:
          X_valdation[col]=0

X_valdation=X_valdation[my_45_columns]
num_cols=X_train.select_dtypes(include=["int64","float64"]).columns
cat_col=X_train.select_dtypes(include=["object"]).columns
numeric_tranform=Pipeline([
     ("imouter",SimpleImputer(strategy="mean")),
     ("scaler",StandardScaler())

])
categorical_transformer=Pipeline([
     ("imputer",SimpleImputer(strategy="most_frequent")),
     ("onehot", OneHotEncoder(handle_unknown="ignore"))
]
     
)
from sklearn.compose import ColumnTransformer
import optuna
preprocessor=ColumnTransformer([
     ("num",numeric_tranform,num_cols),
     ("cat",categorical_transformer,cat_col)
])
def objective(trial,model_name="xgb"):
     if model_name=="xgb":
          params={
               "n_estimators": trial.suggest_int("n_estimators", 100, 500),
            "max_depth": trial.suggest_int("max_depth", 3, 10),
            "learning_rate": trial.suggest_float("learning_rate", 0.01, 0.3),
            "subsample": trial.suggest_float("subsample", 0.5, 1.0),
            "colsample_bytree": trial.suggest_float("colsample_bytree", 0.5, 1.0),
            "random_state": 42,
            "tree_method": "hist"
          }
          model = XGBRegressor(**params)
     elif model_name == "Ridge":
      alpha = trial.suggest_float("alpha", 0.0001, 10.0, log=True)
      model = Ridge(alpha=alpha, random_state=42)

     
     elif model_name == "catboost":
        params = {
            "iterations": trial.suggest_int("iterations", 100, 500),
            "depth": trial.suggest_int("depth", 4, 10),
            "learning_rate": trial.suggest_float("learning_rate", 0.01, 0.3),
            "random_seed": 42,
            "verbose": 0
        }
        model = CatBoostRegressor(**params)
     pipe = Pipeline([
        ("preprocessor", preprocessor),
        ("model", model)
    ])
     pipe.fit(X_train, y_train)
     preds_val = pipe.predict(X_valdation)
     rmse = np.sqrt(mean_squared_error(y_valdation, preds_val))
     return rmse
best_pipes = {}
for model_name in ["xgb", "Ridge", "catboost"]:
     study = optuna.create_study(direction="minimize")
     study.optimize(lambda trial: objective(trial, model_name), n_trials=10)
     print(f" {model_name.upper()} bast pramar:", study.best_params)
     print(f" {model_name.upper()}  best RMSE:", study.best_value)
     if model_name == "xgb":
      best_model = XGBRegressor(**study.best_params)
     elif model_name == "Ridge":
        best_model = Ridge(**study.best_params)
     else:
        best_model = CatBoostRegressor(**study.best_params)
     final_pipe = Pipeline([
        ("preprocessor", preprocessor),
        ("model", best_model)
    ])
     final_pipe.fit(X_train, y_train)
     best_pipes[model_name] = final_pipe
X_test = testing[[c for c in my_45_columns if c in testing.columns]].copy()
for col in my_45_columns:
    if col not in X_test.columns:
        X_test.loc[:, col] = 0
X_test = X_test[my_45_columns]
for model_name, pipe in best_pipes.items():
    preds = pipe.predict(X_test)
output_file = f"predictions_{model_name.upper()}_Optuna.csv"
pd.DataFrame({"prediction": preds}).to_csv(output_file, index=False)
import joblib  

model_name = "my_model"
final_model_file = f"{model_name}.pkl"

joblib.dump(model, final_model_file)
print( final_model_file)

# %% [markdown]
# XGB bast pramar: {'n_estimators': 480, 'max_depth': 3, 'learning_rate': 0.07621060190927734, 'subsample': 0.8562783088976659, 'colsample_bytree': 0.9965577667855621}
#  XGB  best RMSE: 0.8080581224838677
#
#
#
#  RIDGE bast pramar: {'alpha': 0.000272018138695179}
#  RIDGE  best RMSE: 1.8783649248570626e-05
#
#
#
#
#  CATBOOST bast pramar: {'iterations': 128, 'depth': 4, 'learning_rate': 0.2986216878338336}
#  CATBOOST  best RMSE: 0.14396775180775034
